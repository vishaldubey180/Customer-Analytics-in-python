# %% [markdown]
# # Customer Analytics In Python

# %% [markdown]
# we will learn below topics

# %% [markdown]
# - **Relevant Theory**
#
# (to start customer analytics
#
# - **Cluster analysis and dimensionality reduction**
#
# (it helps us to segemnt the customer)
#
# - **Descriptive Statistics**
#
# (an exploratory part of analysis
#
# - **Elasticity modeling**
#
# (for purchase probability,brand choice and purchase quantity)
#
# - **deep learning**
#
# (to predict future behaiour)

# %% [markdown]
# Let's go one by one

# %% [markdown]
# 1. we will explore segmentation targeting and postioning framework

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ![5.JPG](attachment:5.JPG)

# %% [markdown]
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# ![8.JPG](attachment:8.JPG)

# %% [markdown]
# ![9.JPG](attachment:9.JPG)

# %% [markdown]
# ![10.JPG](attachment:10.JPG)

# %% [markdown]
# ![11.JPG](attachment:11.JPG)

# %% [markdown]
# ![12.JPG](attachment:12.JPG)
